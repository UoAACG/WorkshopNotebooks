# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc,rcParams
rc('text', usetex=True)
rcParams['figure.figsize'] = (9, 6)
rcParams['ytick.labelsize'],rcParams['xtick.labelsize'] = 17.,17.
rcParams['axes.labelsize']=19.
rcParams['legend.fontsize']=17.
rcParams['axes.titlesize']=20.
rcParams['text.latex.preamble'] = ['\\usepackage{siunitx}']
import seaborn
seaborn.despine()
seaborn.set_style('white', {'xes.linewidth': 0.5, 'axes.edgecolor':'black'})
seaborn.despine(left=True)

# %%
data=np.array([25.,21.,18.,17.,17.,16.,16.,14.,13.,10.,10.,10.])

# %%
names=['Aqr','Psc','Ari','Tau','Gem','Cnc',
      'Leo','Vir','Lib','Sco','Sgr','Cap']

# %%
data=np.array([37,33,29,42,35,57,41,31,65,49,42,38])

# %%
N=data.sum()
N
# Out:
# 499

# %%
plt.bar(names,data,label='Data')
# Out:
# <BarContainer object of 12 artists>

# %%
p=1/12
mu=N*p
var=((p)*(1-p))*N
sd=np.sqrt(var)
mu,var,sd
# Out:
# (41.58333333333333, 38.11805555555555, 6.173982147330485)

# %%
plt.bar(names,data,width=0.65,label='Data')
plt.hlines(mu,0,11,linestyles='--',label='Expected Value',alpha=0.7)
plt.fill_between(range(12),(mu-sd)*np.ones(12),(mu+sd)*np.ones(12),alpha=0.65,label='Standard Deviation')
plt.legend(loc=2)

# %%
seaborn.distplot(data,rug=True)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
x2=np.sum((N*p-data)**2/(N*p))
x2
# Out:
# 30.370741482965936

# %%
from scipy.stats import chi2

# %%
chi2.pdf(xx,11).max()
# Out:
# 0.09228802399123695

# %%
xx=np.linspace(0,1.5*x2,100)
plt.plot(xx,chi2.pdf(xx,11))
plt.vlines(x2,0,chi2.pdf(xx,11).max()/4,linestyles='--',alpha=0.4)
plt.fill_between(xx[xx<x2],0,chi2.pdf(xx,11)[xx<x2],alpha=0.25)
#plt.hlines(0.05,xx[0],xx[-1])

# %%
import scipy.integrate as integrate

# %%
def f(x): return chi2.pdf(x,11)

# %%
integrate.quad(f,x2,100)[0]#/integrate.quad(f,0,100)[0]
# Out:
# 0.0013854097499910764

# %%
plt.bar(range(1,13),data,label='Data')
plt.hlines(N*p,1,12,linestyles='--',label='Expected Values')
plt.fill_between(range(1,13),(N*p-np.sqrt(var))*np.ones(12),(N*p+np.sqrt(var))*np.ones(12))

# %%
xx=np.linspace(0,30)
plt.plot(xx,chi2.sf(xx,11))
plt.hlines(0.05,xx[0],xx[-1])

# %%
from scipy.stats import chisquare
chisquare(f_obs=data,f_exp=p*N)
# Out:
# Power_divergenceResult(statistic=30.370741482965936, pvalue=0.0013854097499912668)

# %%
plt.bar(range(1,13),data,label='Data')
plt.hlines(N*p,1,12,linestyles='--',label='Expected Values')
plt.fill_between(range(1,13),(N*p-np.sqrt(var))*np.ones(12),(N*p+np.sqrt(var))*np.ones(12))
